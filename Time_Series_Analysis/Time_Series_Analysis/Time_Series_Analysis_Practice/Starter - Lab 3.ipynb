# %% [markdown]
# # Setup

# %%
# %cd /content/drive/MyDrive/Python - Time Series Forecasting/Time Series Analysis/Time Series Analysis Practice
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Python - Time Series Forecasting/Time Series Analysis/Time Series Analysis Practice'
# /home/tzvikifisher/projects/time_series/time_series_forcasting_udemy/Time_Series_Analysis/Time_Series_Analysis/Time_Series_Analysis_Practice

# %%
# Load Pandas
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# # Lab 1

# %%
# Load the data
df = pd.read_csv("department-sales.csv", index_col= 0, parse_dates=True)
df.head()
# Out:
#             Weekly_Sales  IsHoliday
# Date
# 05/02/2010      24924.50      False
# 12/02/2010      46039.49       True
# 19/02/2010      41595.55      False
# 26/02/2010      19403.54      False
# 05/03/2010      21827.90      False

# %%
# Change date format to yyyy-mm-dd
df.index = pd.to_datetime(df.index, format="%d/%m/%Y")
df.head()
# Out:
#             Weekly_Sales  IsHoliday
# Date
# 2010-02-05      24924.50      False
# 2010-02-12      46039.49       True
# 2010-02-19      41595.55      False
# 2010-02-26      19403.54      False
# 2010-03-05      21827.90      False

# %%
# Set index frequency to weekly
df.index.freq = "W-FRI"

# %% [markdown]
# # Lab 2

# %%
# Build a simple Data Visualization with matplotlib
plt.figure(figsize=(12,8))
plt.plot(df.Weekly_Sales)
plt.title("Weekly Sales")
plt.show()

# %%
# Include a vertical line when IsHoliday is True
plt.figure(figsize=(12,8))
plt.plot(df.Weekly_Sales)

for date, row in df.iterrows():
    if row['IsHoliday']:
        plt.axvline(date, color='red', linestyle='--', lw=1)

plt.title("Weekly Sales")
plt.show()

# %% [markdown]
# # Lab 3 - ACF, PACF & Decomposition
#
# * Plot the ACF of Weekly_Sales with 60 lags
#
# * Plot the PACF of Weekly_Sales with 60 lags
#
# * Perform multiplicative seasonal decomposition with period=52

# %%
fig, ax = plt.subplots(figsize = (12, 6))
plot_acf(df['Weekly_Sales'], lags = 60, ax = ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (12, 6))
plot_pacf(df['Weekly_Sales'], lags = 60, ax = ax)
plt.show()

# %%
decomposition = seasonal_decompose(df['Weekly_Sales'],
                                  model = 'multiplicative',
                                  period = 52)
fig = decomposition.plot()
fig.set_size_inches(18, 10)
plt.show()
